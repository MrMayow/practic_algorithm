# %%
import numpy as np
import csv
from pathlib import Path
import scipy.io
from scipy.signal import resample_poly
import pandas as pd

# %%
from pathlib import Path
files = []
directory = Path('Data/48')
output_dir = Path('Data/9kn')
for file in directory.iterdir():
    if file.is_file():
        files.append(file)

# %%
for file_path in files: 
    
    Bearing_data = scipy.io.loadmat(file_path)
    print(Bearing_data.keys())
    label = None
    for key in Bearing_data.keys():
        if "DE_time" in key:
            label = key
            break
  
    signal = Bearing_data[label].flatten()
    up = 3
    down = 4  # 12kHz * 3/4 = 9kHz
    resampled_signal = resample_poly(signal, up, down)
    print(f"Было точек: {len(signal)}")      
    print(f"Стало точек: {len(resampled_signal)}")  
    Bearing_data[label] = [[x] for x in resampled_signal]
    file_name = file_path.name
    scipy.io.savemat(str(output_dir) + "/" + file_name, Bearing_data)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X118_DE_time', 'X118_FE_time', 'X118_BA_time', 'X118RPM'])
# Было точек: 122571
# Стало точек: 91929
# dict_keys(['__header__', '__version__', '__globals__', 'X119_DE_time', 'X119_FE_time', 'X119_BA_time', 'X119RPM'])
# Было точек: 121410
# Стало точек: 91058
# dict_keys(['__header__', '__version__', '__globals__', 'X120_DE_time', 'X120_FE_time', 'X120_BA_time', 'X120RPM'])
# Было точек: 121556
# Стало точек: 91167
# dict_keys(['__header__', '__version__', '__globals__', 'X121_DE_time', 'X121_FE_time', 'X121_BA_time', 'X121RPM'])
# Было точек: 121556
# Стало точек: 91167
# dict_keys(['__header__', '__version__', '__globals__', 'X185_DE_time', 'X185_FE_time', 'X185_BA_time', 'X185RPM'])
# Было точек: 121846
# Стало точек: 91385
# dict_keys(['__header__', '__version__', '__globals__', 'X186_DE_time', 'X186_FE_time', 'X186_BA_time', 'X186RPM'])
# Было точек: 122136
# Стало точек: 91602
# c:\Users\scree\Desktop\bearings\.venv\Lib\site-packages\scipy\io\matlab\_mio.py:317: MatWriteWarning: Starting field name with a underscore (__header__) is ignored
#   MW.put_variables(mdict)
# c:\Users\scree\Desktop\bearings\.venv\Lib\site-packages\scipy\io\matlab\_mio.py:317: MatWriteWarning: Starting field name with a underscore (__version__) is ignored
#   MW.put_variables(mdict)
# c:\Users\scree\Desktop\bearings\.venv\Lib\site-packages\scipy\io\matlab\_mio.py:317: MatWriteWarning: Starting field name with a underscore (__globals__) is ignored
#   MW.put_variables(mdict)
# dict_keys(['__header__', '__version__', '__globals__', 'X187_DE_time', 'X187_FE_time', 'X187_BA_time', 'X187RPM'])
# Было точек: 121991
# Стало точек: 91494
# dict_keys(['__header__', '__version__', '__globals__', 'X188_DE_time', 'X188_FE_time', 'X188_BA_time', 'X188RPM'])
# Было точек: 122136
# Стало точек: 91602
# dict_keys(['__header__', '__version__', '__globals__', 'X222_DE_time', 'X222_FE_time', 'X222_BA_time', 'X222RPM'])
# Было точек: 121991
# Стало точек: 91494
# dict_keys(['__header__', '__version__', '__globals__', 'X223_DE_time', 'X223_FE_time', 'X223_BA_time', 'X223RPM'])
# Было точек: 121701
# Стало точек: 91276
# dict_keys(['__header__', '__version__', '__globals__', 'X224_DE_time', 'X224_FE_time', 'X224_BA_time', 'X224RPM'])
# Было точек: 122136
# Стало точек: 91602
# dict_keys(['__header__', '__version__', '__globals__', 'X225_DE_time', 'X225_FE_time', 'X225_BA_time', 'X225RPM'])
# Было точек: 122136
# Стало точек: 91602
# dict_keys(['__header__', '__version__', '__globals__', 'X048_DE_time'])
# Было точек: 120801
# Стало точек: 90601
# dict_keys(['__header__', '__version__', '__globals__', 'X049_DE_time'])
# Было точек: 121351
# Стало точек: 91014
# dict_keys(['__header__', '__version__', '__globals__', 'X050_DE_time'])
# Было точек: 120984
# Стало точек: 90738
# dict_keys(['__header__', '__version__', '__globals__', 'X051_DE_time'])
# Было точек: 120984
# Стало точек: 90738
# dict_keys(['__header__', '__version__', '__globals__', 'X105_DE_time', 'X105_FE_time', 'X105_BA_time', 'X105RPM'])
# Было точек: 121265
# Стало точек: 90949
# dict_keys(['__header__', '__version__', '__globals__', 'X106_DE_time', 'X106_FE_time', 'X106_BA_time', 'X106RPM'])
# Было точек: 121991
# Стало точек: 91494
# dict_keys(['__header__', '__version__', '__globals__', 'X107_DE_time', 'X107_FE_time', 'X107_BA_time', 'X107RPM'])
# Было точек: 122136
# Стало точек: 91602
# dict_keys(['__header__', '__version__', '__globals__', 'X108_DE_time', 'X108_FE_time', 'X108_BA_time', 'X108RPM'])
# Было точек: 122917
# Стало точек: 92188
# dict_keys(['__header__', '__version__', '__globals__', 'X169_DE_time', 'X169_FE_time', 'X169_BA_time', 'X169RPM'])
# Было точек: 121846
# Стало точек: 91385
# dict_keys(['__header__', '__version__', '__globals__', 'X170_DE_time', 'X170_FE_time', 'X170_BA_time', 'X170RPM'])
# Было точек: 121846
# Стало точек: 91385
# dict_keys(['__header__', '__version__', '__globals__', 'X171_DE_time', 'X171_FE_time', 'X171_BA_time', 'X171RPM'])
# Было точек: 121846
# Стало точек: 91385
# dict_keys(['__header__', '__version__', '__globals__', 'X172_DE_time', 'X172_FE_time', 'X172_BA_time', 'X172RPM'])
# Было точек: 121701
# Стало точек: 91276
# dict_keys(['__header__', '__version__', '__globals__', 'X209_DE_time', 'X209_FE_time', 'X209_BA_time', 'X209RPM'])
# Было точек: 122136
# Стало точек: 91602
# dict_keys(['__header__', '__version__', '__globals__', 'X210_DE_time', 'X210_FE_time', 'X210_BA_time', 'X210RPM'])
# Было точек: 121556
# Стало точек: 91167
# dict_keys(['__header__', '__version__', '__globals__', 'X211_DE_time', 'X211_FE_time', 'X211_BA_time', 'X211RPM'])
# Было точек: 121846
# Стало точек: 91385
# dict_keys(['__header__', '__version__', '__globals__', 'X212_DE_time', 'X212_FE_time', 'X212_BA_time', 'X212RPM'])
# Было точек: 121991
# Стало точек: 91494
# dict_keys(['__header__', '__version__', '__globals__', 'X056_DE_time'])
# Было точек: 120801
# Стало точек: 90601
# dict_keys(['__header__', '__version__', '__globals__', 'X057_DE_time'])
# Было точек: 121351
# Стало точек: 91014
# dict_keys(['__header__', '__version__', '__globals__', 'X058_DE_time'])
# Было точек: 121351
# Стало точек: 91014
# dict_keys(['__header__', '__version__', '__globals__', 'X059_DE_time'])
# Было точек: 121535
# Стало точек: 91152
# dict_keys(['__header__', '__version__', '__globals__', 'X097_DE_time', 'X097_FE_time', 'X097RPM'])
# Было точек: 243938
# Стало точек: 182954
# dict_keys(['__header__', '__version__', '__globals__', 'X098_DE_time', 'X098_FE_time'])
# Было точек: 483903
# Стало точек: 362928
# dict_keys(['__header__', '__version__', '__globals__', 'ans', 'X098_DE_time', 'X098_FE_time', 'X099_DE_time', 'X099_FE_time'])
# Было точек: 483903
# Стало точек: 362928
# dict_keys(['__header__', '__version__', '__globals__', 'X100_DE_time', 'X100_FE_time', 'X100RPM'])
# Было точек: 485643
# Стало точек: 364233
# dict_keys(['__header__', '__version__', '__globals__', 'X156_DE_time', 'X156_FE_time', 'X156_BA_time', 'X156RPM'])
# Было точек: 122281
# Стало точек: 91711
# dict_keys(['__header__', '__version__', '__globals__', 'X158_DE_time', 'X158_FE_time', 'X158_BA_time', 'X158RPM'])
# Было точек: 121991
# Стало точек: 91494
# dict_keys(['__header__', '__version__', '__globals__', 'X159_DE_time', 'X159_FE_time', 'X159_BA_time', 'X159RPM'])
# Было точек: 122281
# Стало точек: 91711
# dict_keys(['__header__', '__version__', '__globals__', 'X160_DE_time', 'X160_FE_time', 'X160_BA_time', 'X160RPM'])
# Было точек: 122136
# Стало точек: 91602
# dict_keys(['__header__', '__version__', '__globals__', 'X144_DE_time', 'X144_FE_time', 'X144_BA_time', 'X144RPM'])
# Было точек: 122281
# Стало точек: 91711
# dict_keys(['__header__', '__version__', '__globals__', 'X145_DE_time', 'X145_FE_time', 'X145_BA_time', 'X145RPM'])
# Было точек: 121846
# Стало точек: 91385
# dict_keys(['__header__', '__version__', '__globals__', 'X146_DE_time', 'X146_FE_time', 'X146_BA_time', 'X146RPM'])
# Было точек: 121556
# Стало точек: 91167
# dict_keys(['__header__', '__version__', '__globals__', 'X147_DE_time', 'X147_FE_time', 'X147_BA_time', 'X147RPM'])
# Было точек: 122281
# Стало точек: 91711
# dict_keys(['__header__', '__version__', '__globals__', 'X130_DE_time', 'X130_FE_time', 'X130_BA_time', 'X130RPM'])
# Было точек: 121991
# Стало точек: 91494
# dict_keys(['__header__', '__version__', '__globals__', 'X131_DE_time', 'X131_FE_time', 'X131_BA_time', 'X131RPM'])
# Было точек: 122426
# Стало точек: 91820
# dict_keys(['__header__', '__version__', '__globals__', 'X132_DE_time', 'X132_FE_time', 'X132_BA_time', 'X132RPM'])
# Было точек: 121410
# Стало точек: 91058
# dict_keys(['__header__', '__version__', '__globals__', 'X133_DE_time', 'X133_FE_time', 'X133_BA_time', 'X133RPM'])
# Было точек: 122571
# Стало точек: 91929
# dict_keys(['__header__', '__version__', '__globals__', 'X197_DE_time', 'X197_FE_time', 'X197_BA_time', 'X197RPM'])
# Было точек: 121846
# Стало точек: 91385
# dict_keys(['__header__', '__version__', '__globals__', 'X198_DE_time', 'X198_FE_time', 'X198_BA_time', 'X198RPM'])
# Было точек: 122136
# Стало точек: 91602
# dict_keys(['__header__', '__version__', '__globals__', 'X199_DE_time', 'X199_FE_time', 'X199_BA_time', 'X199RPM'])
# Было точек: 121846
# Стало точек: 91385
# dict_keys(['__header__', '__version__', '__globals__', 'X200_DE_time', 'X200_FE_time', 'X200_BA_time', 'X200RPM'])
# Было точек: 121991
# Стало точек: 91494
# dict_keys(['__header__', '__version__', '__globals__', 'X258_DE_time', 'X258_FE_time', 'X258_BA_time', 'X258RPM'])
# Было точек: 121846
# Стало точек: 91385
# dict_keys(['__header__', '__version__', '__globals__', 'X259_DE_time', 'X259_FE_time', 'X259_BA_time', 'X259RPM'])
# Было точек: 122426
# Стало точек: 91820
# dict_keys(['__header__', '__version__', '__globals__', 'X260_DE_time', 'X260_FE_time', 'X260_BA_time', 'X260RPM'])
# Было точек: 122716
# Стало точек: 92037
# dict_keys(['__header__', '__version__', '__globals__', 'X261_DE_time', 'X261_FE_time', 'X261_BA_time', 'X261RPM'])
# Было точек: 121701
# Стало точек: 91276
# dict_keys(['__header__', '__version__', '__globals__', 'X246_DE_time', 'X246_FE_time', 'X246_BA_time', 'X246RPM'])
# Было точек: 121701
# Стало точек: 91276
# dict_keys(['__header__', '__version__', '__globals__', 'X247_DE_time', 'X247_FE_time', 'X247_BA_time', 'X247RPM'])
# Было точек: 121991
# Стало точек: 91494
# dict_keys(['__header__', '__version__', '__globals__', 'X248_DE_time', 'X248_FE_time', 'X248_BA_time', 'X248RPM'])
# Было точек: 122281
# Стало точек: 91711
# dict_keys(['__header__', '__version__', '__globals__', 'X249_DE_time', 'X249_FE_time', 'X249_BA_time', 'X249RPM'])
# Было точек: 122136
# Стало точек: 91602
# dict_keys(['__header__', '__version__', '__globals__', 'X234_DE_time', 'X234_FE_time', 'X234_BA_time', 'X234RPM'])
# Было точек: 122426
# Стало точек: 91820
# dict_keys(['__header__', '__version__', '__globals__', 'X235_DE_time', 'X235_FE_time', 'X235_BA_time', 'X235RPM'])
# Было точек: 121991
# Стало точек: 91494
# dict_keys(['__header__', '__version__', '__globals__', 'X236_DE_time', 'X236_FE_time', 'X236_BA_time', 'X236RPM'])
# Было точек: 122281
# Стало точек: 91711
# dict_keys(['__header__', '__version__', '__globals__', 'X237_DE_time', 'X237_FE_time', 'X237_BA_time', 'X237RPM'])
# Было точек: 121991
# Стало точек: 91494
