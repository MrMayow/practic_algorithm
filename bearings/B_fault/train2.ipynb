# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
# === Параметры ===
WINDOW_SIZE = 512      # длина окна (сэмпла)
STRIDE = 256            # шаг окна
BATCH_SIZE = 32
EPOCHS = 3
LEARNING_RATE = 1e-3
CONFIDENCE_THRESHOLD = 0.7  # порог уверенности для "отказа от ответа"

# %%
def load_csv_files(folder, label):
    samples = []
    labels = []
    for fname in os.listdir(folder):
        if fname.endswith('.csv'):
            df = pd.read_csv(os.path.join(folder, fname))
            v = df['vibration'].values
            # Разбиваем на окна
            for start in range(0, len(v) - WINDOW_SIZE + 1, STRIDE):
                window = v[start:start+WINDOW_SIZE]
                samples.append(window)
                labels.append(label)
    return samples, labels

# %%
# === Класс датасета ===
class VibrationDataset(Dataset):
    def __init__(self, data, labels):
        self.data = torch.tensor(data, dtype=torch.float32).unsqueeze(1)  # [N, 1, WINDOW_SIZE]
        self.labels = torch.tensor(labels, dtype=torch.float32)           # [N]
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# %%
# === Модель ===
class Simple1DCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv1d(1, 16, 7, padding=3)
        self.pool1 = nn.MaxPool1d(2)
        self.conv2 = nn.Conv1d(16, 32, 5, padding=2)
        self.pool2 = nn.MaxPool1d(2)
        self.fc1 = nn.Linear(32 * (WINDOW_SIZE // 4), 64)
        self.fc2 = nn.Linear(64, 1)
    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = self.pool1(x)
        x = torch.relu(self.conv2(x))
        x = self.pool2(x)
        x = x.view(x.size(0), -1)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return torch.sigmoid(x).squeeze(1)

# %%
# Укажите пути к папкам с .csv файлами
normal_folder = 'csv_data/normal'  # без дефекта
defect_folder = 'csv_data/defect'  # с дефектом

print('Загрузка данных...')
X_normal, y_normal = load_csv_files(normal_folder, 0)
X_defect, y_defect = load_csv_files(defect_folder, 1)

X = np.array(X_normal + X_defect)
y = np.array(y_normal + y_defect)

print(f'Всего сэмплов: {len(X)}')

# Разделяем на train/val
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

train_dataset = VibrationDataset(X_train, y_train)
val_dataset = VibrationDataset(X_val, y_val)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# Модель, оптимизатор, функция потерь
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Simple1DCNN().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
criterion = nn.BCELoss()
# Out:
# Загрузка данных...
# Всего сэмплов: 12319

# %%
for epoch in range(EPOCHS):
    model.train()
    total_loss = 0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        preds = model(xb)
        loss = criterion(preds, yb)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * xb.size(0)
    avg_loss = total_loss / len(train_dataset)

    # Валидация
    model.eval()
    val_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            preds = model(xb)
            loss = criterion(preds, yb)
            val_loss += loss.item() * xb.size(0)
            predicted = (preds > 0.5).float()
            correct += (predicted == yb).sum().item()
            total += xb.size(0)
    val_loss /= len(val_dataset)
    val_acc = correct / total
    print(f'Epoch {epoch+1}/{EPOCHS} | Train Loss: {avg_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}')
# Out:
# Epoch 1/3 | Train Loss: 0.0771 | Val Loss: 0.0012 | Val Acc: 0.9996
# Epoch 2/3 | Train Loss: 0.0006 | Val Loss: 0.0003 | Val Acc: 1.0000
# Epoch 3/3 | Train Loss: 0.0001 | Val Loss: 0.0002 | Val Acc: 1.0000

# %%
def predict_with_rejection(model, sample, threshold=CONFIDENCE_THRESHOLD):
        model.eval()
        with torch.no_grad():
            x = torch.tensor(sample, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
            prob = model(x).item()
            if abs(prob - 0.5) < (threshold - 0.5):
                return 'Неуверен'
            return 'Дефект' if prob > 0.5 else 'Нет дефекта'

# %%
torch.save(model.state_dict(), 'vibration_cnn.pth')

# %%
def load_csv_file_to_windows(file_path, window_size=WINDOW_SIZE, stride=STRIDE):
    df = pd.read_csv(file_path)
    v = df['vibration'].values
    windows = []
    for start in range(0, len(v) - window_size + 1, stride):
        window = v[start:start+window_size]
        windows.append(window)
    return windows

# %%
samples = load_csv_file_to_windows("csv_data/normal/Normal_0.csv")
result = predict_with_rejection(model, v, threshold=CONFIDENCE_THRESHOLD)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 samples = load_csv_file_to_windows("csv_data/normal/Normal_0.csv")
# ----> 2 result = predict_with_rejection(model, v, threshold=CONFIDENCE_THRESHOLD)
#       3 print(result)
#
# NameError: name 'v' is not defined

# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np

# ==== Модель ====
class Simple1DCNN(nn.Module):
    def __init__(self, window_size=512):
        super().__init__()
        self.conv1 = nn.Conv1d(1, 16, 7, padding=3)
        self.pool1 = nn.MaxPool1d(2)
        self.conv2 = nn.Conv1d(16, 32, 5, padding=2)
        self.pool2 = nn.MaxPool1d(2)
        self.fc1 = nn.Linear(32 * (window_size // 4), 64)
        self.fc2 = nn.Linear(64, 1)
    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = self.pool1(x)
        x = torch.relu(self.conv2(x))
        x = self.pool2(x)
        x = x.view(x.size(0), -1)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return torch.sigmoid(x).squeeze(1)

# ==== Функция для разбиения на окна ====
def load_csv_file_to_windows(file_path, window_size=512, stride=256):
    df = pd.read_csv(file_path)
    v = df['vibration'].values
    windows = []
    for start in range(0, len(v) - window_size + 1, stride):
        window = v[start:start+window_size]
        windows.append(window)
    return windows

# ==== Основной процесс ====
def predict_file(file_path, model_path='vibration_cnn.pth', window_size=512, stride=256, threshold=0.5, confidence_band=0.2):
    # Загрузка модели
    model = Simple1DCNN(window_size=window_size)
    model.load_state_dict(torch.load(model_path, map_location='cpu'))
    model.eval()

    # Загрузка и разбиение файла
    windows = load_csv_file_to_windows(file_path, window_size=window_size, stride=stride)
    if not windows:
        print("В файле недостаточно данных для одного окна.")
        return

    windows_tensor = torch.tensor(windows, dtype=torch.float32).unsqueeze(1)  # [N, 1, window_size]

    # Предсказания
    with torch.no_grad():
        outputs = model(windows_tensor)
        probs = outputs.numpy()

    # Анализ результатов
    verdicts = []
    for i, prob in enumerate(probs):
        if abs(prob - 0.5) < confidence_band:
            verdict = f'Окно {i}: Неуверен (prob={prob:.3f})'
            verdicts.append('Неуверен')
        elif prob > threshold:
            verdict = f'Окно {i}: Дефект (prob={prob:.3f})'
            verdicts.append('Дефект')
        else:
            verdict = f'Окно {i}: Нет дефекта (prob={prob:.3f})'
            verdicts.append('Нет дефекта')
        print(verdict)

    # Итоговое решение для файла
    if 'Дефект' in verdicts:
        print('\nВ файле обнаружен дефект!')
    elif all(v == 'Неуверен' for v in verdicts):
        print('\nМодель не уверена ни в одном окне.')
    else:
        print('\nДефект не обнаружен.')




predict_file("csv_self_data/defect/50Hz_accelerometer.csv")
# Out:
# Окно 0: Дефект (prob=1.000)
# Окно 1: Дефект (prob=1.000)
# Окно 2: Нет дефекта (prob=0.002)
# Окно 3: Нет дефекта (prob=0.000)
# Окно 4: Нет дефекта (prob=0.000)
# Окно 5: Дефект (prob=1.000)
# Окно 6: Дефект (prob=1.000)
# Окно 7: Нет дефекта (prob=0.015)
# Окно 8: Нет дефекта (prob=0.000)
# Окно 9: Нет дефекта (prob=0.000)
# Окно 10: Дефект (prob=1.000)
# Окно 11: Дефект (prob=1.000)
# Окно 12: Нет дефекта (prob=0.096)
# Окно 13: Нет дефекта (prob=0.000)
# Окно 14: Нет дефекта (prob=0.000)
# Окно 15: Дефект (prob=1.000)
# Окно 16: Дефект (prob=1.000)
# Окно 17: Нет дефекта (prob=0.006)
# Окно 18: Нет дефекта (prob=0.002)
# Окно 19: Нет дефекта (prob=0.001)
# Окно 20: Дефект (prob=1.000)
# Окно 21: Дефект (prob=1.000)
# Окно 22: Нет дефекта (prob=0.010)
# Окно 23: Нет дефекта (prob=0.000)
# Окно 24: Нет дефекта (prob=0.000)
# Окно 25: Дефект (prob=1.000)
# Окно 26: Дефект (prob=1.000)
# Окно 27: Нет дефекта (prob=0.001)
# Окно 28: Нет дефекта (prob=0.000)
# Окно 29: Нет дефекта (prob=0.000)
# Окно 30: Дефект (prob=1.000)
# Окно 31: Дефект (prob=1.000)
# Окно 32: Нет дефекта (prob=0.002)
# Окно 33: Нет дефекта (prob=0.001)
# Окно 34: Нет дефекта (prob=0.000)
# Окно 35: Дефект (prob=1.000)
# Окно 36: Дефект (prob=1.000)
# Окно 37: Нет дефекта (prob=0.000)
# Окно 38: Нет дефекта (prob=0.000)
# Окно 39: Нет дефекта (prob=0.000)
# Окно 40: Дефект (prob=1.000)
# Окно 41: Дефект (prob=1.000)
# Окно 42: Нет дефекта (prob=0.000)
# Окно 43: Нет дефекта (prob=0.000)
# Окно 44: Нет дефекта (prob=0.003)
# Окно 45: Дефект (prob=1.000)
# Окно 46: Дефект (prob=1.000)
# Окно 47: Нет дефекта (prob=0.000)
# Окно 48: Нет дефекта (prob=0.002)
# Окно 49: Дефект (prob=0.826)
# Окно 50: Дефект (prob=1.000)
# Окно 51: Дефект (prob=1.000)
# Окно 52: Нет дефекта (prob=0.000)
# Окно 53: Нет дефекта (prob=0.000)
# Окно 54: Дефект (prob=1.000)
# Окно 55: Дефект (prob=1.000)
# Окно 56: Дефект (prob=1.000)
# Окно 57: Нет дефекта (prob=0.000)
# Окно 58: Нет дефекта (prob=0.000)
# Окно 59: Дефект (prob=0.975)
# Окно 60: Дефект (prob=1.000)
# Окно 61: Дефект (prob=1.000)
# Окно 62: Нет дефекта (prob=0.000)
# Окно 63: Нет дефекта (prob=0.000)
# Окно 64: Дефект (prob=0.997)
# Окно 65: Дефект (prob=1.000)
# Окно 66: Дефект (prob=0.998)
# Окно 67: Нет дефекта (prob=0.000)
# Окно 68: Нет дефекта (prob=0.000)
# Окно 69: Дефект (prob=1.000)
# Окно 70: Дефект (prob=1.000)
# Окно 71: Дефект (prob=0.823)
# Окно 72: Нет дефекта (prob=0.000)
# Окно 73: Нет дефекта (prob=0.000)
# Окно 74: Дефект (prob=0.999)
# Окно 75: Дефект (prob=1.000)
# Окно 76: Нет дефекта (prob=0.067)
# Окно 77: Нет дефекта (prob=0.001)
# Окно 78: Нет дефекта (prob=0.002)
# Окно 79: Дефект (prob=1.000)
# Окно 80: Дефект (prob=1.000)
# Окно 81: Дефект (prob=0.972)
# Окно 82: Нет дефекта (prob=0.000)
# Окно 83: Нет дефекта (prob=0.000)
# Окно 84: Дефект (prob=1.000)
# Окно 85: Дефект (prob=1.000)
# Окно 86: Нет дефекта (prob=0.070)
# Окно 87: Нет дефекта (prob=0.017)
# Окно 88: Нет дефекта (prob=0.016)
# Окно 89: Дефект (prob=1.000)
# Окно 90: Дефект (prob=1.000)
# Окно 91: Дефект (prob=1.000)
# Окно 92: Нет дефекта (prob=0.001)
# Окно 93: Нет дефекта (prob=0.000)
# Окно 94: Дефект (prob=1.000)
# Окно 95: Дефект (prob=1.000)
# Окно 96: Нет дефекта (prob=0.055)
# Окно 97: Нет дефекта (prob=0.003)
# Окно 98: Нет дефекта (prob=0.003)
# Окно 99: Дефект (prob=1.000)
# Окно 100: Дефект (prob=1.000)
# Окно 101: Дефект (prob=0.951)
# Окно 102: Нет дефекта (prob=0.003)
# Окно 103: Нет дефекта (prob=0.000)
# Окно 104: Дефект (prob=1.000)
# Окно 105: Дефект (prob=1.000)
# Окно 106: Нет дефекта (prob=0.001)
# Окно 107: Нет дефекта (prob=0.000)
# Окно 108: Нет дефекта (prob=0.000)
# Окно 109: Дефект (prob=1.000)
# Окно 110: Дефект (prob=1.000)
# Окно 111: Нет дефекта (prob=0.002)
# Окно 112: Нет дефекта (prob=0.000)
# Окно 113: Нет дефекта (prob=0.002)
# Окно 114: Дефект (prob=1.000)
# Окно 115: Дефект (prob=1.000)
# Окно 116: Нет дефекта (prob=0.001)
# Окно 117: Нет дефекта (prob=0.000)
# Окно 118: Нет дефекта (prob=0.000)
# Окно 119: Дефект (prob=1.000)
# Окно 120: Дефект (prob=1.000)
# Окно 121: Нет дефекта (prob=0.000)
# Окно 122: Нет дефекта (prob=0.000)
# Окно 123: Дефект (prob=0.823)
# Окно 124: Дефект (prob=1.000)
# Окно 125: Дефект (prob=1.000)
# Окно 126: Нет дефекта (prob=0.001)
# Окно 127: Нет дефекта (prob=0.000)
# Окно 128: Дефект (prob=0.974)
# Окно 129: Дефект (prob=1.000)
# Окно 130: Дефект (prob=0.995)
# Окно 131: Нет дефекта (prob=0.000)
# Окно 132: Нет дефекта (prob=0.001)
# Окно 133: Нет дефекта (prob=0.015)
# Окно 134: Дефект (prob=1.000)
# Окно 135: Дефект (prob=1.000)
# Окно 136: Нет дефекта (prob=0.000)
# Окно 137: Нет дефекта (prob=0.000)
# Окно 138: Дефект (prob=1.000)
# Окно 139: Дефект (prob=1.000)
# Окно 140: Неуверен (prob=0.427)
# Окно 141: Нет дефекта (prob=0.001)
# Окно 142: Нет дефекта (prob=0.001)
# Окно 143: Неуверен (prob=0.670)
# Окно 144: Дефект (prob=1.000)
# Окно 145: Дефект (prob=0.998)
# Окно 146: Нет дефекта (prob=0.002)
# Окно 147: Нет дефекта (prob=0.002)
# Окно 148: Дефект (prob=1.000)
# Окно 149: Дефект (prob=1.000)
# Окно 150: Дефект (prob=1.000)
# Окно 151: Нет дефекта (prob=0.013)
# Окно 152: Нет дефекта (prob=0.000)
# Окно 153: Дефект (prob=1.000)
# Окно 154: Дефект (prob=1.000)
# Окно 155: Неуверен (prob=0.364)
# Окно 156: Нет дефекта (prob=0.000)
# Окно 157: Нет дефекта (prob=0.000)
# Окно 158: Дефект (prob=1.000)
# Окно 159: Дефект (prob=1.000)
# Окно 160: Дефект (prob=1.000)
# Окно 161: Нет дефекта (prob=0.001)
# Окно 162: Нет дефекта (prob=0.005)
# Окно 163: Дефект (prob=1.000)
# Окно 164: Дефект (prob=1.000)
# Окно 165: Дефект (prob=0.979)
# Окно 166: Нет дефекта (prob=0.001)
# Окно 167: Нет дефекта (prob=0.001)
# Окно 168: Дефект (prob=1.000)
# Окно 169: Дефект (prob=1.000)
# Окно 170: Неуверен (prob=0.457)
# Окно 171: Нет дефекта (prob=0.002)
# Окно 172: Нет дефекта (prob=0.001)
# Окно 173: Дефект (prob=1.000)
# Окно 174: Дефект (prob=1.000)
# Окно 175: Нет дефекта (prob=0.010)
# Окно 176: Нет дефекта (prob=0.002)
# Окно 177: Нет дефекта (prob=0.002)
# Окно 178: Дефект (prob=1.000)
# Окно 179: Дефект (prob=1.000)
# Окно 180: Нет дефекта (prob=0.036)
# Окно 181: Нет дефекта (prob=0.000)
# Окно 182: Нет дефекта (prob=0.001)
# Окно 183: Дефект (prob=1.000)
# Окно 184: Дефект (prob=1.000)
# Окно 185: Нет дефекта (prob=0.024)
# Окно 186: Нет дефекта (prob=0.002)
# Окно 187: Нет дефекта (prob=0.000)
# Окно 188: Дефект (prob=1.000)
# Окно 189: Дефект (prob=1.000)
# Окно 190: Нет дефекта (prob=0.002)
# Окно 191: Нет дефекта (prob=0.000)
# Окно 192: Нет дефекта (prob=0.019)
# Окно 193: Дефект (prob=1.000)
# Окно 194: Дефект (prob=1.000)
# Окно 195: Нет дефекта (prob=0.048)
# Окно 196: Нет дефекта (prob=0.000)
# Окно 197: Нет дефекта (prob=0.189)
# Окно 198: Дефект (prob=1.000)
# Окно 199: Дефект (prob=1.000)
# Окно 200: Нет дефекта (prob=0.004)
# Окно 201: Нет дефекта (prob=0.004)
# Окно 202: Нет дефекта (prob=0.002)
# Окно 203: Дефект (prob=1.000)
# Окно 204: Дефект (prob=1.000)
# Окно 205: Нет дефекта (prob=0.000)
# Окно 206: Нет дефекта (prob=0.000)
# Окно 207: Дефект (prob=1.000)
# Окно 208: Дефект (prob=1.000)
# Окно 209: Дефект (prob=0.995)
# Окно 210: Нет дефекта (prob=0.000)
# Окно 211: Нет дефекта (prob=0.000)
# Окно 212: Нет дефекта (prob=0.104)
# Окно 213: Дефект (prob=1.000)
# Окно 214: Дефект (prob=0.999)
# Окно 215: Нет дефекта (prob=0.000)
# Окно 216: Нет дефекта (prob=0.000)
# Окно 217: Дефект (prob=1.000)
# Окно 218: Дефект (prob=1.000)
# Окно 219: Неуверен (prob=0.582)
# Окно 220: Нет дефекта (prob=0.000)
# Окно 221: Нет дефекта (prob=0.000)
# Окно 222: Дефект (prob=1.000)
# Окно 223: Дефект (prob=1.000)
# Окно 224: Дефект (prob=0.817)
# Окно 225: Нет дефекта (prob=0.000)
# Окно 226: Нет дефекта (prob=0.001)
# Окно 227: Дефект (prob=1.000)
# Окно 228: Дефект (prob=1.000)
# Окно 229: Дефект (prob=0.984)
# Окно 230: Нет дефекта (prob=0.000)
# Окно 231: Нет дефекта (prob=0.000)
# Окно 232: Дефект (prob=1.000)
# Окно 233: Дефект (prob=1.000)
# Окно 234: Нет дефекта (prob=0.044)
# Окно 235: Нет дефекта (prob=0.000)
# Окно 236: Нет дефекта (prob=0.000)
# Окно 237: Дефект (prob=1.000)
# Окно 238: Дефект (prob=1.000)
# Окно 239: Нет дефекта (prob=0.018)
# Окно 240: Нет дефекта (prob=0.000)
# Окно 241: Нет дефекта (prob=0.000)
# Окно 242: Дефект (prob=1.000)
# Окно 243: Дефект (prob=1.000)
# Окно 244: Нет дефекта (prob=0.031)
# Окно 245: Нет дефекта (prob=0.000)
# Окно 246: Нет дефекта (prob=0.001)
# Окно 247: Дефект (prob=1.000)
# Окно 248: Дефект (prob=1.000)
# Окно 249: Нет дефекта (prob=0.124)
# Окно 250: Нет дефекта (prob=0.000)
# Окно 251: Нет дефекта (prob=0.000)
# Окно 252: Дефект (prob=1.000)
# Окно 253: Дефект (prob=1.000)
# Окно 254: Нет дефекта (prob=0.006)
# Окно 255: Нет дефекта (prob=0.000)
# Окно 256: Нет дефекта (prob=0.000)
# Окно 257: Дефект (prob=1.000)
# Окно 258: Дефект (prob=1.000)
# Окно 259: Нет дефекта (prob=0.000)
# Окно 260: Нет дефекта (prob=0.000)
# Окно 261: Нет дефекта (prob=0.000)
# Окно 262: Дефект (prob=1.000)
# Окно 263: Дефект (prob=1.000)
# Окно 264: Нет дефекта (prob=0.002)
# Окно 265: Нет дефекта (prob=0.000)
# Окно 266: Нет дефекта (prob=0.000)
# Окно 267: Дефект (prob=1.000)
# Окно 268: Дефект (prob=1.000)
# Окно 269: Нет дефекта (prob=0.000)
# Окно 270: Нет дефекта (prob=0.000)
# Окно 271: Нет дефекта (prob=0.000)
# Окно 272: Дефект (prob=1.000)
# Окно 273: Дефект (prob=1.000)
# Окно 274: Нет дефекта (prob=0.000)
# Окно 275: Нет дефекта (prob=0.000)
# Окно 276: Нет дефекта (prob=0.003)
# Окно 277: Дефект (prob=1.000)
# Окно 278: Дефект (prob=1.000)
# Окно 279: Нет дефекта (prob=0.001)
# Окно 280: Нет дефекта (prob=0.001)
# Окно 281: Дефект (prob=0.996)
# Окно 282: Дефект (prob=1.000)
# Окно 283: Дефект (prob=0.996)
# Окно 284: Нет дефекта (prob=0.000)
# Окно 285: Нет дефекта (prob=0.000)
# Окно 286: Дефект (prob=1.000)
# Окно 287: Дефект (prob=1.000)
# Окно 288: Дефект (prob=1.000)
# Окно 289: Нет дефекта (prob=0.000)
# Окно 290: Нет дефекта (prob=0.000)
# Окно 291: Дефект (prob=0.973)
# Окно 292: Дефект (prob=1.000)
# Окно 293: Дефект (prob=0.999)
# Окно 294: Нет дефекта (prob=0.001)
# Окно 295: Нет дефекта (prob=0.000)
# Окно 296: Дефект (prob=1.000)
# Окно 297: Дефект (prob=1.000)
# Окно 298: Дефект (prob=0.977)
# Окно 299: Нет дефекта (prob=0.000)
# Окно 300: Нет дефекта (prob=0.000)
# Окно 301: Дефект (prob=0.997)
# Окно 302: Дефект (prob=1.000)
# Окно 303: Неуверен (prob=0.540)
# Окно 304: Нет дефекта (prob=0.000)
# Окно 305: Нет дефекта (prob=0.000)
# Окно 306: Дефект (prob=1.000)
# Окно 307: Дефект (prob=1.000)
# Окно 308: Дефект (prob=0.868)
# Окно 309: Нет дефекта (prob=0.000)
# Окно 310: Нет дефекта (prob=0.000)
# Окно 311: Дефект (prob=1.000)
# Окно 312: Дефект (prob=1.000)
# Окно 313: Нет дефекта (prob=0.238)
# Окно 314: Нет дефекта (prob=0.000)
# Окно 315: Нет дефекта (prob=0.000)
# Окно 316: Дефект (prob=1.000)
# Окно 317: Дефект (prob=1.000)
# Окно 318: Неуверен (prob=0.471)
# Окно 319: Нет дефекта (prob=0.000)
# Окно 320: Нет дефекта (prob=0.000)
# Окно 321: Дефект (prob=1.000)
# Окно 322: Дефект (prob=1.000)
# Окно 323: Нет дефекта (prob=0.002)
# Окно 324: Нет дефекта (prob=0.000)
# Окно 325: Нет дефекта (prob=0.000)
# Окно 326: Дефект (prob=1.000)
# Окно 327: Дефект (prob=1.000)
# Окно 328: Нет дефекта (prob=0.047)
# Окно 329: Нет дефекта (prob=0.000)
# Окно 330: Нет дефекта (prob=0.000)
# Окно 331: Дефект (prob=1.000)
# Окно 332: Дефект (prob=1.000)
# Окно 333: Нет дефекта (prob=0.276)
# Окно 334: Нет дефекта (prob=0.000)
# Окно 335: Нет дефекта (prob=0.000)
# Окно 336: Дефект (prob=1.000)
# Окно 337: Дефект (prob=1.000)
# Окно 338: Нет дефекта (prob=0.000)
# Окно 339: Нет дефекта (prob=0.000)
# Окно 340: Нет дефекта (prob=0.138)
# Окно 341: Дефект (prob=1.000)
# Окно 342: Дефект (prob=1.000)
# Окно 343: Нет дефекта (prob=0.005)
# Окно 344: Нет дефекта (prob=0.000)
# Окно 345: Дефект (prob=0.942)
# Окно 346: Дефект (prob=1.000)
# Окно 347: Дефект (prob=1.000)
# Окно 348: Нет дефекта (prob=0.002)
# Окно 349: Нет дефекта (prob=0.000)
#
# В файле обнаружен дефект!
# /tmp/ipykernel_18153/937123188.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location='cpu'))
